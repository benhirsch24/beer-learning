# %%
import urllib2
import os
import numpy
from bs4 import BeautifulSoup
import collections
from urlparse import urljoin
import csv

# %%
dataDir = os.path.join('/'.join(os.getcwd().split('/')[0:-1]), 'data')
# Out:
# /Users/hirschb/Personal/beer-learning/data

# %%
class Ingredient:
    def __init__(self, ingredient_html):
        self.headings = []
        self.data = []
        
        self.parse(ingredient_html)
        
    def parse(self, html):
        for heading in html.thead.tr.find_all("th"):
            self.headings.append(heading.get_text())
        for ferm in html.tbody.find_all("tr"):
            f_dat = []
            
            fermentable = [f.get_text() for f in ferm.find_all("td")]
            # Cleaning up names a bit
            for field in fermentable:
                field_name = field.encode('ascii', 'ignore').strip()
                
                # turn \n into spaces
                field_name = ''.join([f if f != '\n' else ' ' for f in field_name])
                
                # remove multiple spaces
                name = []
                space = False
                for f in field_name:
                    if f == ' ':
                        if not space:
                            space = True
                            name.append(f)
                    else:
                        if space:
                            space = False
                        name.append(f)
                f_dat.append(''.join(name))
            self.data.append(f_dat)

class Fermentables(Ingredient):
    def __init__(self, fermentables_html):
        Ingredient.__init__(self, fermentables_html)
        
class Hops(Ingredient):
    def __init__(self, hops_html):
        Ingredient.__init__(self, hops_html)

class Yeast(Ingredient):
    def __init__(self, yeast_html):
        Ingredient.__init__(self, yeast_html)
        
class Recipe:
    def __init__(self, relative_link, site_url):
        self.url = urljoin(site_url, relative_link)
        self.name = relative_link.split('/')[-1]
        self.filename = os.path.join(dataDir, 'recipes_html', self.name + '.html')
        self.csvfilename = os.path.join(dataDir, 'recipes', self.name + '.csv')
        
        self.stats = {}
        self.recipe_html = None
        
        print self.name
        
    """
    Downloads the recipe to the recipes_html directory
    """
    def download(self):
        recipe_html = urllib2.urlopen(self.url).read()
        with open(self.filename, 'w') as f:
            f.write(recipe_html)

    """
    Parses the Recipe from a file on the filesystem 
    in dataDir / recipes_html / recipe_name
    
    If download=True this will force a re-download and 
                                     re-parse into csv
    """
    def parse(self, download=False, reparse=False):
        if download or not os.path.isfile(self.filename):
            self.download()
        
        if not download and not reparse and os.path.isfile(self.csvfilename):
            with open(self.filename) as f:
                recipe_csv = csv.reader(f)
                print 'Parsing ' + self.name + ' with CSV'
                self.parseCSV()
                return
        
        if self.recipe_html is None:
            with open(self.filename) as f:
                recipe_html = f.read()
            
        recipesoup = BeautifulSoup(recipe_html, 'html.parser')
        
        # Parses the stats, OG/FG/etc
        stats_html = recipesoup.find_all("div", class_="recipe-show--stats")[0]
        for stat in stats_html.find_all("div", class_="horizontal-bar-graph"):
            label = stat.find("div", class_="label").get_text()
            value = stat.find("div", class_="value").get_text()
            if label == 'ABV':
                value = value[0:-1]

            if label in ['OG', 'FG', 'ABV']:
                value = float(value)
            else:
                value = int(value)
            self.stats[label] = value

        ingredients_html = recipesoup.find_all("div", class_="recipe-show--ingredients")[0]
        for ingredient_html in ingredients_html.find_all("table"):
            ingredient = ingredient_html['id']
            if ingredient == 'fermentables':
                self.fermentables = Fermentables(ingredient_html)
            elif ingredient == 'hops':
                self.hops = Hops(ingredient_html)
            elif ingredient == 'yeasts':
                self.yeast = Yeast(ingredient_html)
                
                
    def parseCSV(self):
        with open(self.csvfilename, 'r') as f:
            recipe_csv = csv.reader(self.csvfilename)
            self.stats = recipe_csv.next()
            print self.stats
            
    def writeCSV(self):
        lines = [ ','.join(self.stats.iterkeys()),
                ','.join([str(v) for v in self.stats.itervalues()]) ]
        def addIngredient(ingr):
            lines.append(','.join(self.fermentables.headings))
            for d in ingr.data:
                lines.append(','.join(d))
        addIngredient(self.fermentables)
        addIngredient(self.hops)
        addIngredient(self.yeast)
        with open(self.csvfilename, 'w') as f:
            f.write('\n'.join(lines))

# %%
def download(url, recipe_link, download=False, reparse=False):
    recipe_link = url + recipe_link
    index_file = os.path.join(dataDir, 'index.html')
    if not os.path.isfile(index_file):
        contents = urllib2.urlopen(recipe_link).read()
        with open(index_file, 'w') as f:
            f.write(contents)
    else:
        with open(index_file, 'r') as f:
            contents = f.read()
    
    soup = BeautifulSoup(contents, 'html.parser')
    recipe_links = [a['href'] for a in soup.find_all("a", class_="recipe-link")]
    
    for relative_link in recipe_links:
        recipe = Recipe(relative_link, url)
        recipe.parse(download=download, reparse=reparse)
        recipe.writeCSV()

download("https://www.brewtoad.com/", "recipes?page=1&sort=rank", reparse=True)
print 'Done downloading'
# Out:
# firework-cream-ale
# [['8.0 lb', 'American 2-Row', 'Rahr', 'Mash', '38', '1 L'], ['2.0 lb', 'Corn, Flaked', 'Any', 'Mash', '37', '1 L'], ['1.0 lb', 'Crystal 15', 'Great Western', 'Mash', '10', '15 L'], ['1.0 lb', 'CarapilsMalt', 'Briess', 'Mash', '34', '1 L']]
# cascade-ipa-e15d96
# [['11.5 lb', 'American 2-Row', 'Rahr', 'Mash', '38', '1 L'], ['0.5 lb', 'Caramel Malt 60L', 'Briess', 'Mash', '34', '60 L']]
# 3-floyds-zombie-dust-clone
# [['12.75 lb', '2-Row (US)', 'Any', 'Mash', '37', '1 L'], ['1.25 lb', 'Munich Malt 10L', 'Briess', 'Mash', '35', '10 L'], ['0.5 lb', 'CARAPILS', 'Weyermann', 'Mash', '33', '1 L'], ['0.5 lb', 'Melanoidin Malt', 'Weyermann', 'Mash', '37', '26 L'], ['0.5 lb', 'Caramel Malt 60L', 'Briess', 'Mash', '34', '60 L']]
# nut-brown-ale-102
# [['8.0 lb', 'Maris Otter', 'Bairds', 'Mash', '35', '3 L'], ['1.0 lb', 'Oats, Flaked', 'Any', 'Mash', '37', '1 L'], ['1.0 lb', 'VictoryMalt', 'Briess', 'Mash', '34', '28 L'], ['1.0 lb', 'Caramel Malt 120L', 'Briess', 'Mash', '32', '120 L'], ['0.25 lb', 'CARAFA III', 'Weyermann', 'Mash', '32', '525 L']]
# lemon-saison-1
# [['3.31 lb', 'Pilsen Light LME', 'Briess', 'Late Boil', '37', '2 L'], ['2.69 lb', 'Pilsen Light DME', 'Briess', 'Boil', '44', '2 L'], ['1.0 lb', 'Honey Malt', 'Gambrinus', 'Steep', '37', '23 L']]
# hefe-iv
# [['5.5 lb', 'American 2-Row', 'Rahr', 'Mash', '38', '1 L'], ['4.0 lb', 'Wheat Malt, White', 'Briess', 'Mash', '39', '2 L'], ['0.5 lb', 'Vienna Malt', 'Briess', 'Mash', '35', '3 L'], ['0.5 lb', 'CarapilsMalt', 'Briess', 'Mash', '34', '1 L']]
# citra-black-ipa-bc7279
# [['6.0 lb', 'Golden Light LME', 'Briess', 'Boil', '37', '4 L'], ['1.0 lb', '2-Row Caramel Malt 60L', 'Briess', 'Steep', '34', '60 L'], ['1.0 lb', 'Corn Sugar (Dextrose)', 'Any', 'Boil', '46', '0 L'], ['0.75 lb', 'Black Malt', 'Briess', 'Steep', '32', '500 L']]
# big-bens-brown-ale
# [['8.0 lb', 'American 2-Row', 'Rahr', 'Mash', '38', '1 L'], ['1.0 lb', 'Munich Malt 10L', 'Briess', 'Mash', '35', '10 L'], ['0.75 lb', 'Caramel Malt 120L', 'Briess', 'Mash', '32', '120 L'], ['0.5 lb', 'Chocolate Malt', 'Bairds', 'Mash', '32', '475 L']]
# belgian-pale-62
# [['8.25 lb', 'Pilsner (BE)', 'Any', 'Mash', '37', '1 L'], ['1.2 lb', 'Flaked Wheat', 'Any', 'Mash', '34', '2 L'], ['0.7 lb', 'CaraVienne (BE)', 'Any', 'Mash', '34', '20 L'], ['0.5 lb', 'Biscuit (BE)', 'Any', 'Mash', '35', '23 L'], ['0.5 lb', 'Caramel/Crystal 60L (US)', 'Any', 'Mash', '34', '60 L']]
# woodys-wit
# [['4.5 lb', '2-Row (US)', 'Any', 'Mash', '37', '1 L'], ['3.5 lb', 'Wheat Malt, White', 'Briess', 'Mash', '39', '2 L'], ['1.0 lb', 'Flaked Wheat', 'Any', 'Mash', '34', '2 L'], ['0.75 lb', 'Flaked Oats', 'Any', 'Mash', '33', '2 L'], ['0.5 lb', 'Rice Hulls', 'Any', 'Mash', '0', '0 L']]
# house-red-ale
# [['6.0 lb', 'Dry Malt Extract - Light', 'Any', 'Boil', '42', '4 L'], ['0.75 lb', 'CaraMunich III (DE)', 'Any', 'Steep', '34', '57 L'], ['0.25 lb', 'Roasted Barley (UK)', 'Any', 'Steep', '29', '550 L']]
# citra-amarillo-ipa
# [['12.5 lb', '2-Row (US)', 'Briess', 'Mash', '35', '2 L'], ['2.0 lb', 'Vienna (US)', 'Briess', 'Mash', '35', '4 L'], ['0.5 lb', 'Carapils (Dextrine Malt) (US)', 'Briess', 'Mash', '33', '1 L'], ['0.25 lb', 'Caramel/Crystal 60L (US)', 'Briess', 'Mash', '34', '60 L']]
# sierra-nevada-pale-ale-clone-65
# [['11.0 lb', '2-Row (US)', 'Any', 'Mash', '37', '1 L'], ['10.08 oz', 'Caramel/Crystal 60L (US)', 'Any', 'Mash', '34', '60 L']]
# vanilla-bourbon-stout-18
# [['7.0 lb', 'Liquid Malt Extract - Amber', 'Any', 'Boil', '35', '10 L'], ['1.0 lb', 'Caramel/Crystal 40L (US)', 'Any', 'Steep', '34', '40 L'], ['1.0 lb', 'Chocolate (BE)', 'Any', 'Steep', '30', '340 L'], ['0.5 lb', 'Oat Malt (UK)', 'Any', 'Steep', '28', '2 L'], ['0.5 lb', 'Roasted Barley (US)', 'Any', 'Steep', '33', '300 L']]
# love-you-long-time-ipa
# [['5.0 lb', '2-Row (US)', 'Any', 'Mash', '37', '1 L'], ['2.0 lb', 'Carapils (DE)', 'Any', 'Mash', '35', '1 L'], ['1.25 lb', 'Caramel/Crystal 40L (US)', 'Any', 'Mash', '34', '40 L'], ['1.0 lb', 'Flaked wheat', 'Any', 'Mash', '38', '1 L']]
# grapefruit-ipa-87c8c3
# [['6.25 lb', 'Liquid Malt Extract - Amber', 'Any', 'Boil', '35', '10 L'], ['1.0 lb', 'Vienna (UK)', 'Any', 'Steep', '35', '4 L'], ['1.0 lb', 'White Wheat (US)', 'Any', 'Steep', '40', '2 L'], ['0.5 lb', 'Pale 2-Row (US)', 'Any', 'Steep', '37', '1 L'], ['0.5 lb', 'Honey Malt (CA)', 'Any', 'Steep', '37', '25 L'], ['0.25 lb', 'Caramel/Crystal 40L (US)', 'Any', 'Steep', '34', '40 L']]
# all-citra-ale
# [['7.0 lb', 'Golden Light DME', 'Briess', 'Boil', '43', '4 L'], ['0.5 lb', 'Caramel Malt 40L', 'Briess', 'Steep', '34', '40 L']]
# springtime-red-ipa
# [['11.0 lb', 'Maris Otter Pale (UK)', 'Any', 'Mash', '38', '3 L'], ['10.08 oz', 'CaraHell (DE)', 'Any', 'Mash', '34', '11 L'], ['10.08 oz', 'CaraMunich (BE)', 'Any', 'Mash', '33', '50 L'], ['8.0 oz', 'CaraRed (DE)', 'Any', 'Mash', '34', '20 L'], ['2.08 oz', 'Carafa III (DE)', 'Any', 'Mash', '32', '535 L']]
# hoegaarden-clone-26
# [['4.0 lb', 'Pilsen Malt', 'Briess', 'Mash', '36', '1 L'], ['4.0 lb', 'Wheat Malt', 'Gambrinus', 'Mash', '38', '2 L'], ['1.0 lb', 'Wheat, Flaked', 'Any', 'Mash', '34', '2 L'], ['1.0 lb', 'Oats, Flaked', 'Any', 'Mash', '37', '1 L']]
# robust-porter-v3
# [['9.0 lb', 'Maris Otter Pale Ale Malt', 'Thomas Fawcett & Sons', 'Mash', '36', '2 L'], ['1.5 lb', 'Munich Malt 10L', 'Briess', 'Mash', '35', '10 L'], ['0.75 lb', 'Caramel Malt 40L', 'Briess', 'Mash', '34', '40 L'], ['0.5 lb', 'Chocolate Wheat Malt', 'Any', 'Mash', '33', '400 L'], ['0.5 lb', 'Black Malt', 'Briess', 'Mash', '32', '500 L']]
# wee-heavy-51
# [['17.5 lb', 'Maris Otter', 'Bairds', 'Mash', '35', '3 L'], ['1.0 lb', 'Crystal 40', 'Great Western', 'Mash', '32', '40 L'], ['0.5 lb', 'Munich Malt 10L', 'Briess', 'Mash', '35', '10 L'], ['0.5 lb', 'Honey Malt', 'Gambrinus', 'Mash', '37', '23 L'], ['0.25 lb', 'Crystal 120', 'Great Western', 'Mash', '32', '120 L'], ['0.25 lb', 'Pale Chocolate Malt', 'Thomas Fawcett & Sons', 'Mash', '32', '197 L']]
# bells-two-hearted-beersmith
# [['13.0 lb', 'Maris Otter Pale (UK)', 'Any', 'Mash', '38', '3 L'], ['2.0 lb', 'Vienna (DE)', 'Any', 'Mash', '37', '4 L'], ['8.0 oz', 'Caramel/Crystal 20L (US)', 'Any', 'Mash', '35', '20 L'], ['8.0 oz', 'Carapils (Dextrine Malt) (US)', 'Any', 'Mash', '33', '1 L']]
# german-pilsner-8
# [['9.92 lb', 'Pilsner Malt', 'Weyermann', 'Mash', '37', '1 L'], ['1.1 lb', 'CarapilsMalt', 'Briess', 'Mash', '34', '1 L']]
# october-sky-fresh-hop-brown-ale
# [['7.0 lb', 'Light LME', 'Muntons', 'Boil', '37', '4 L'], ['0.5 lb', 'Chocolate Malt', 'Briess', 'Steep', '34', '350 L'], ['0.5 lb', '2-Row Caramel Malt 60L', 'Briess', 'Steep', '34', '60 L']]
# honey-citra-pale
# [['7.0 lb', 'Maris Otter Pale (UK)', 'Any', 'Mash', '38', '3 L'], ['0.5 lb', 'Bonlander Munich (US)', 'Any', 'Mash', '36', '10 L'], ['0.5 lb', 'Caramel/Crystal 60L (US)', 'Any', 'Mash', '34', '60 L'], ['0.5 lb', 'Amber (UK)', 'Any', 'Mash', '32', '27 L'], ['0.5 lb', 'Honey', 'Any', 'Late Boil', '42', '2 L']]
# proper-job
# [['10.0 lb', 'Finest Maris Otter Ale Malt', 'Crisp', 'Mash', '38', '3 L'], ['0.5 lb', 'Munich Malt 10L', 'Briess', 'Mash', '35', '10 L'], ['0.5 lb', '2-Row Caramel Malt 60L', 'Briess', 'Mash', '34', '60 L']]
# citripa
# [['12.0 lb', 'Maris Otter Pale Ale Malt', 'Thomas Fawcett & Sons', 'Mash', '36', '2 L'], ['1.0 lb', 'Caramel Malt 40L', 'Briess', 'Mash', '34', '40 L']]
# moose-drool-2
# [['7.19 lb', 'Golden Light LME', 'Briess', 'Boil', '37', '4 L'], ['1.0 lb', 'Caramel Malt 80L', 'Briess', 'Steep', '33', '80 L'], ['0.37 lb', 'Chocolate Malt', 'Briess', 'Steep', '34', '350 L'], ['0.03 lb', 'Black Malt', 'Bairds', 'Steep', '30', '550 L']]
# snow-shovel-helles-2011-06-09-version
# [['10.0 lb', 'Pilsner Malt', 'Weyermann', 'Mash', '37', '1 L'], ['0.5 lb', 'Munich Malt', "Simpson's", 'Mash', '35', '7 L'], ['0.12 lb', 'Melanoidin Malt', 'Any', 'Mash', '37', '20 L']]
# Done downloading
